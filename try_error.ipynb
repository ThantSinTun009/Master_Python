# %% [markdown]
# ## Try/except keywords

# %%
numerator = float(input("Enter number: "))
denominator    = float(input("Enter denominator: "))         
quotient = numerator / denominator
print(f'The quotient is {quotient}.')

# 10 and 3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 numerator = float(input("Enter number: "))
#       2 denominator    = float(input("Enter denominator: "))
#       3 quotient = numerator / denominator
#
# ValueError: could not convert string to float: ''

# %%
numerator = float(input("Enter number: "))
denominator    = float(input("Enter denominator: "))         
quotient = numerator / denominator
print(f'The quotient is {quotient}.')

# 10, Green
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 numerator = float(input("Enter number: "))
# ----> 2 denominator    = float(input("Enter denominator: "))
#       3 quotient = numerator / denominator
#       4 print(f'The quotient is {quotient}.')
#
# ValueError: could not convert string to float: 'Green'

# %% [markdown]
# Applying Error Handling

# %%
try:
    numerator = float(input("Enter number: "))
    denominator    = float(input("Enter denominator: "))         
    quotient = numerator / denominator
    print(f'The quotient is {quotient}.')
except:
    print("Invalid input. Please enter a number")
    
# Input : 10, Green
# Out:
# Invalid input. Please enter a number

# %%
# For another kind of problems/errors
try:
    numerator = float(input("Enter number: "))
    denominator    = float(input("Enter denominator: "))         
    quotient = numerator / denominator
    print(f'The quotient is {quotient}.')
except ValueError:
    print("Invalid input. Please enter a number")
except ZeroDivisionError:
    print("Invalid Input. Please enter a non-zero denominator")
# Out:
# Invalid Input. Please enter a non-zero denominator
